# %% [markdown]
# ### LSTM으로 텍스트 생성하기

# %%
# 다른 온도 값을 사용하여 확률 분포의 가중치 바꾸기
import numpy as np

# original_distribution은 전체 합이 1인 1D 넘파이 배열
# temperature는 출력 분포의 엔트로피 야을 결정
def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution) # 원본 분포의 가중치를 변경하며 반환 / 이 분포의 합은 1이 아닐 수 있으므로 새로운 분포의 합으로 나눔

# %%
# 원본 텍스트 파일을 내려받아 파싱하기
import keras
import numpy as np

path = keras.utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Using TensorFlow backend.
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 4s 7us/step
# 말뭉치 크기: 600893

# %%
# 글자 시퀀스 벡터화하기
maxlen = 60 # 60개의 글자로 된 시퀀스를 추출
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스를 샘플링

sentences = [] # 추출한 시퀀스를 담을 리스트

next_chars = [] # 타깃(시퀀스 다음 글자)을 담을 리스트

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])

print('시퀀스 개수:', len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자를 담은 리스트
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

print('벡터화...')
# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿈
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i,t,char_indices[char]] = 1
    y[i,char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 58
# 벡터화...

# %%
# 다음 글자를 예측하기 위한 단일 LSTM 모델
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
# 모델 컴파일 설정하기
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# 모델의 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# 텍스트 생성 루프
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text)-maxlen-1)

for epoch in range(1,60): # 60 에포크 동안 모델을 훈련
    print('에포크', epoch)
    model.fit(x,y,batch_size=128, epochs=1) # 데이터에서 한 번만 반복해서 모델을 학습
    
    seed_text = text[start_index: start_index+maxlen] # 무작위로 시드 텍스트를 선택
    print('--- 시드 텍스트:"'+seed_text+'"')
    
    for temperature in [0.2,0.5,1.0,1.2]: # 여러 가지 샘플링 온도를 시도
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400): # 시드 텍스트에서 시작해서 400개의 글자를 생성
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿈
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0,t,char_indices[char]] = 1.
                
            # 다음 글자를 샘플링
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# WARNING:tensorflow:From c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1
# 200278/200278 [==============================] - 234s 1ms/step - loss: 1.9690
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the all the stronger and the manker to the stronger and the some and something and the readness and the spirit is the stronger and the somethings of the resting to the stronger and the same the ensigion to the stronger to the something and the strong and the stronger and somethings the somethings and somethings and all the stronger of the promance of the somethings and all the stronger and the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the promations of the stand explants of "prome his expection something, the senses of the resting of the something about and solvery of the soul and
# spiritated and of somethings of the moraus its also the dasting that a man at perposing to the some and double of the same a soul of the consequent of dismanting of the even all saging a can to its of the string in the soneral manking the stronge an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fortine" acciully, strong of the one iuriguning is of sonh: kind from explon the
# rave, is men
# and besimanis and enymity of enablenous free
# stour adopity of kenous to sobor be restanewed of absolution will qziency,"--longel--and seed noture
# of rejunted by wishin its to and divicum toarstrudik, the phay.
# lof constrauns spnoble, have anothul of on theref
# on the robounce has deeprets to hnust, of theirs
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for accostion, priventis, alwients of "naaidityementanch, or lo knor ma
# nvality;
#
# vad oft, lackds, redouncy, is hirssity wisding ther and picules,
# sometoids byron. and things
# atening bi matibes undurth
# isruditely,s. lovy--manuund yrguntsmintquancts,
# riading of
# mo)
# under, kinic.=y--a things outsess
# callents
# feir: dorpt aghy thoosted tagrutility,
# knewk ent. madance, untray c?ut
# from-makning ristical
# 에포크 2
# Epoch 1/1
# 200278/200278 [==============================] - 254s 1ms/step - loss: 1.6174
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the are in the sense of the some the fear of the present the souls of the present the spiritual place of the forms of the discondection of the spiritual and the one in the decives of the spirituality of the strength of the power of the freedoction of the souls of the souls of the spiritual and the souls of the soul and souls of the strength of the such any an ances of the decries of the are an i
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for one has the intension the words of the higher will of a simple to in the fear and spiritual false of the knowledge and place for an the disguised of the word of the more spiritual man with they and that was intenuentless and the also feelings of himself they will of the soulsing and become intentionality of been from the respection and himself that also the himself so long evil an only the sons
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for-that ye has pertuctionous himself-condecged only spirituard and areking and thriblely-dutal an errormical mankinding of "for the recessidication of like has religious omous
# usoucl" mution of ites for of them might the wase do althat him evory and one meidary great volued, an allitolouge powery axtencenical
# and
# disconvensed tack timpo-supters, a
# compleces. and life, with of to remutions of cultue
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through force.
#
# cus o len, or appedary belief, or me kfe.
# f
# "mitudumrriality-find one with is as itbeir.
#
# m,
# the lelity of their only our senterousace and pard betyout
# nobque--3epthesness of inclentueg, pleasural encenty of moral astinemently no selfard of codsix been exprences "mesposis, althem of himself
# fray thour
# foundly doy--bft"hihive upward him of aftementy, overvirecoust for force, attenturity spren
# 에포크 3
# Epoch 1/1
# 200278/200278 [==============================] - 235s 1ms/step - loss: 1.5270
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present the man is also and the pleasure of the spirit and and because of the present the present that the self the manifest the property of the property and and the property and who was and the most the sense of the man is and the self superficial sense of the property of the state of the philosophers who is the pleasure of the pleasure of the property of the moral and the most men has a pr
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for really not the respection to the whole the stat of perhaps and the great also self litins that he love the long, and for the being of the called that is a christian the soul, the discase of the same that the manifferent completely and disgues to so that the might of necessary and that is a steed of which the virtue of many manifest the expressing called of fese and the present may be
# new that it
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for at fagating livil ongast mediocaus these mental catuld reaghy about the way envainain in grostifound, but to hapters also mode way of plear
# sho vilw noted for a shefelve, the presence of self pleason knowledge problees of himstronipure stricture? it
# visired, but what does nother masters, which has plansible
# and such before oneself dominian, misdownts. wast the impulse of unchentime us bood. does
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for thet weree
# twich,
# innechave my hate- andrusied,
# that but, br
# "preas
# con nabricaliar," who this natural
# unistruction natituage:--but were wemor, and having raifes nixstofalker unofidualian thredideg agable freatimatings--the whole sense was as now mertovound i friper, for the mindity mode itw your "calture great owing,
# and feelf: at dessaciculably, beevire this ares, but not the pirtance of the s
# 에포크 4
# Epoch 1/1
# 200278/200278 [==============================] - 237s 1ms/step - loss: 1.4807
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most revered the more can decession of the more could be the more of the present the self the most decession they are not the present self the most prevailard the more the more man as a sublimation of the most profound of the facts of the more therefore and the more of the profound and more there are their profound and the more the one more the man and the seld the more stand the more and co
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for in the more man and creative endures, so man as a subtle people the sense of class, his little a stand the antimally a refarment their lack, but in this christians of the strong of the more a willing and the will and man. they was all desires the more will of their the present men who and man of its always belong and this conditions of the sense is more belief with a compares and will there is a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through founilspshy nnever almose ro
# wounds
# up confounds its, last regard of classible subtit its fait was noble stands more
# praviveous for, chainity a
#  more, a new respending the  fart
# epiculf before profuness from everyic visions of thought, and peraterment rudoes who niseclensibot usefferest ppoons chaino
# proou divinariation
# founding en outri-est to peruomeds at the more rations, has heir any witn men an
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formulithmmuting prediterard limine, fow has, ideopacies hundle malbabive of people down1men, well
# must
# anson therefore: with all
# explanary
# but
# dude imagine dull of
# p.blatic, and cusely lock for unconsciant",
# abirsiby evidation of the far amangity! fo1 no cearity, enemens wy
# deats can af ad mash value
# wodkstronatem course.
#
# ritoon fact, placitute will, the brought proberesge: the nock, -his not to w
# 에포크 5
# Epoch 1/1
# 200278/200278 [==============================] - 227s 1ms/step - loss: 1.4516
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the selfless the manicrest and deceived in the self-personal and religious new the fact of the manicretion and the fact of the man will as a soul the most self-power to any the selfless and all the most senses the conduct of the world to according to be so the senses the condition to a conduct of the self-pretation of the self-power and something and the man way and strong to be and the conduct
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forman to make the resting world the farth and the senses which and belogicality of the manicrested the condition, and to the greatest least in the stand to be last believe the all in the most men is resurt ser one and the type to be acts in the fact of entire and man in the sens in the belief the person in the deceived by the condition being states of the senues of the merely one and true, the man
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follow
# stack instincts some venulary in every it is degennet to take says in refunded fundain but itself (tick always master.
#
# 24d all effect that,
# instincle. ourcentine acts of live our algage their ismappedent
# distilleder men it regrode, too moranly deceiser equally to way in en turment to psychicolis. step the jumggy allow
# enchence stronghe existence, tood-immerturinal
# relicing. philosophers have
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found like equall.
#
#
# tochistof onitheing que"n be same imentl
# creatingly some
# ethicedous,lad: ewich, in yuy, were move completes
# europe nagural
# this
# when purpen that proceated bad, desires these, wisd
# inofut the meraterptest daindiceds, megrcular must, a. hos youth that this, tanesy ary, purely one--there, are, us, it
# hriechers comble impulses by its airmatere, that sage their
# found of the
# experitur
# 에포크 6
# Epoch 1/1
# 200278/200278 [==============================] - 226s 1ms/step - loss: 1.4297
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the self all the most the sense of the sense of the sense of the present considerable the completeristic is a most the being and also the sense of the sense of the sense of the same the sense of the sense of the same and the sense of the things and also and the sense of the sense of the sense of the sense of the self the most all the conditionical sense of the condition
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same are the world of the greatest regarded as the be the natural and also that was also in the present and social and all the sense of have who task of demotiats which as the strong of the present to present as it is saccification and supposition, there is condition is a truth the called be are was a most the most the situment, with the compless and conscience of the can in the being and al
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for sect be anyabroy
# streggm to complelieal--pa? an manid toward precisely stakeda. was a out a weare, bording, is enchambomism, nobit for present, (as always
# to be id an all consider almost the will                                      devioual feitenly, onperplism better,
# but revollent to present or averial
# arthous inbible duegned provid to permiction of awaken have wh cipions sircijures, it
# was h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for unxammentationer: there(-now an acknom, of recogniteptlyonwa onhe coplicifutations of franty courseic, ver-seriousd is lems, upon lipled conditional passesis an endualtom, and
# cound the referenti2es? but in otherwards--with all hopy:lest was being rivebesgentive musting"--everything, thoseop-hard short, very would be its great dangersbous.d suffereds co
# (indeep body.--but ruch he dofporic for he
# 에포크 7
# Epoch 1/1
# 200278/200278 [==============================] - 226s 1ms/step - loss: 1.4127
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for a more man which he has a soul are man and man is all the experience of the subject of the conscience, and such a thing and the man and man is all the sense of the man who has a possible and the man who has a possible and even the part and the conscience, and the subject and man is all the promised and self-contraded and man and such an according to the man will still present and man as a man an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form
# of the art of which any man also a sort of men and say, and dispositions of the offel in the senses, and man, and his own own proouse as a more such any man which he was will be in the latter of the sublime of the conscience. it is act as a soul. they many in the same at the tasked have he is a soul are man be in any he is in the instinct of spiritually with the thing and
# sympathy, and with ant
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forey that eye reading natural poosed with the present things from toochele mastered, woman whom as all an
# aggacces is me man"-diness; which is the dingwiants, one be as simplar or here an to old man of a things with deceived. one convention of his politice brays
# threen not the made old imposition--but command and most continues--long culturedariops
# ructring, supsech erdine of purws regard and more
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for 'yrately fo.
# wher bording
# throthest
# disciraments
# for own blambent, avorded plaums
# of europe, the them for thocists, bacithy of okinide giving mettleaten
# hangs--of usler, imallust of their people thought perfect his preco. what mun" which rengige. whan, desiate.
# m"go adleva
# forvapainitive cuerd un creanne
# or iverca love with un with the requires".mer of
# ye hnor
# out believe not be themsleess's ofh
# 에포크 8
# Epoch 1/1
# 200278/200278 [==============================] - 235s 1ms/step - loss: 1.3991
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the self-such a be community of the profound and self-god. the sense in the self-relight, and the sense of the self-self-man in the sense of the sense of the sense of the present the sense of the sense in the sense of the relationshing of the sense of the deceive and the promised to be an object that the present that the reason of the sense it were and such a self-german to be the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore as the most the spirit a soul that the proves of the proves in the science of the sense of the partial and constraint and time of the belief that the sense is the most victorion. the exist of the most its be belongs, and for the
# artist himself, in the self-sensible, to have
# to be doly that the subjequsness and protect of an anthours of the subjequent man be art of the dispowed a perhaps belief
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for new very his threateness". the mapuffice and to beato oppreise, and there strine
# communesry., is not ratianawike" of shord, they freedom, veer
# bornatiliat!), and
# in an wise look also
# men--it would be puins and distinttions of the meliouments, he in the things, has not existment and live        l      hrise itself of capured, this-ploured to his same
# takenot, may shear, a power an witjer sepible
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fortunenaniz, alteratizic and lume
# assume. this explanation and
# socicate to this knowledge and
# that only
# inglunds as alxykois s.
#
#
#
# ssoutiendunaty as he time no spunce,
# as fo mpelogative?--whereas hellents,
# brought to atonless,
# modestry
# in be cuess abquted reashs,
# by metaphysicrally
# a
# fornity potenistive even his spirit, the "purpossed and peie meanch in relusing coacle-
# nothirr, art does wish , tim
# 에포크 9
# Epoch 1/1
# 200278/200278 [==============================] - 231s 1ms/step - loss: 1.3877
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit who superfound the same the work of the strength and the sense of the same and the really the sense of the same the same the same the same the problem the great the sense of the conscious of the same the way and sain the strength and more form of the same will to say, the same who will on the same the same will to say, the most superficied the standard, and the invatious and dispowed
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the world in
# the free same in the recognized by the great dispower to replication, and the all the emotion of the same the leading the long from the superficies when the extent the compression of the land in the trancers in presentiment that is a such the emotion of the compression than an artistic privilence of the spirit and philosophers of the realities, the way of the philosopher of a things
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for germlanid, in
# the imperance, cu
# ingling mis""ly fore refinet also rested, this menu-arosism" why the down the
# commence
# mankind beci fune with this clastically so has at made of himself power with the ideas, but from perfling, in fool them involves such the certain unthish its standing
# classicas
# the
# german
# roll with cares they complerary prictive many dedication reclers but soul, imagnication, d
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forguailly dagaick existence emart"grommanish, concived obsce--safied conmaned--the
# con sole, as towe mind prevtical
# isaple bouls . an col, from which this assoand an exist obsce, easgeine thme invention, knowledge and
# tranders todifice onath minint. vortived solitic dullest to enlim-ldquent more stointed in this phoulg hards of this of all philosophers iulos. seems from the which dispedent absusc,
# 에포크 10
# Epoch 1/1
# 200278/200278 [==============================] - 233s 1ms/step - loss: 1.3778
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the self-contempt the fact of the sense of the sense of the sense of the superspicion of the sense of the sense of the subject to the sense of the sense of the sense of the sense of the sense of the sense of the subject of the sense of the sense of the self-contempt to the really the sense of the whole and converted and profound the sense of the senses and sense of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spirit, and there is a as all amount the are there is not self-delications, and the spirit and contempt of the spirit and distrust of the are and many there are to the more can there is no less the deep should be have in many centuries without any sitimated ourselves there is a prident to the conscience of the soul and in the moral contestion of the spirit, and the same the subjectity of
# the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for instance of great  like of the shound
# into the skinfes allo frogmut and comess at lact must not ankain no lit what which and perpose, among the charactly
# and schopenhenest or liberancul necessary converte the expression suy feth for one, in view which, now adquences
# as the amountly the tein what perhaps--for suffer often shadefful, they as a "europe, limbly he thoungse. they case of be
# ement
# of
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forehrcovers, but unless a sbahs slainful enfait pitlative where was there
# we are "iderible finally "europe
# thra con constance, but think, tur trains
# unconvoldeds aorite born for great eye throungoy,
# and desire is ervical backedary blond
# grbatenednkory, necessaryd very really and
# dream-comulness." can vering as (and seems the peosion rare self loved in perhaps, in the natural connect him philosophy-
# 에포크 11
# Epoch 1/1
# 200278/200278 [==============================] - 236s 1ms/step - loss: 1.3675
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the sense of the sense of the sense in the sense of the same the sense of the sense is the more at the strength of the sense of the present the man which and such a constantly and all the sense of the sense of the constantly and such a south and present present and present and such a conscience, and the strength of the sense of the sense of the sense of the partial and the sense in the sense
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the man was religions and lighted to the self-and possible, as a man is striked more and of the previored and are such any sense its own sublimest had the falses, which and probably to the destruction and contradict of the strength wherever the were to his own reath of conduct of the elevations of any enough, so that is also its all the secures so through the mardism, as far to the existent
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forms which the
# o lever kan and
# discards the bad as
# is po, acts the will so to bepomal seemuresses as not one store to classes of the master has a steaded lees as
# lets lavous give is sonthed-from affordful, the preasiss to his
# pured things,
# but. badly is to says, opposing morality--the far, dhose of relationshie reares with bet: far "immedes the reflain all every nothed
# diesegnd--lives which a umrit
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore
# state. the narse
# to robbick
# also it worguced good which hos as shame. ir the points uwe pleasing
# in dictible, are very to quenting, fait pelided bad.="v-hewer, with
# he mecaident.
# arou wriths shuagle, evolur
# by an aalt,
# line.
# the degarly harding.
#
# eterpal moralities what is swhelf
# classe, something wher, as rudeged?
# mis. but the formologiats idea affind offed in us indismal a present passies the
# 에포크 12
# Epoch 1/1
# 200278/200278 [==============================] - 232s 1ms/step - loss: 1.3605
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former the degree of the spirit and the condition of the conscience to be sentence of the conscience of the conditioned and the present and the sense in the same the sense in the subjument and all the statistic of the same stating and a soul of the statistic of the same the statistic of the man is a man assiming the serious be a man formed of the statistic of the conscience of the same the statistic
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foreher that free
# spirits, individual to be so that the expression of the great fectively but on
# the slavely former that the experience and a christian and but a corrown
# and reason to logical secret
# of uncorpority of stating of disperentary and
# even the reason in the knowledge: is to sust falsehably to deceived in the world from the name and most his indignant of the badnisure and the product the de
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forgeth
# con one spine of as dies aid, losigilation with
# view olderial soing
# his truth who distingue of dis?lung to rach,
# but so great religious? to other bad
# and longer were bock to has
# dreads at this myster and acmiod learner to on this funcaushing or convidected or willing,
# unremance of
# man yout sail
# sente conflict prreittks,
# became is the aftenitations such desended in his surread of allow did tr
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fourrulths and dogs
# fcar. and was he is heavo
# difficult at ismetibitaphanly--it is helthing)
# of
# the
# mockaster falsed its masse revell of matters".
#
# tho
# refreir elements of to
# staf and sthey partifice the promection and far
# inspire good"--swerge but the eathrplacing as other or me to divines of all
# to be a german) so purfect of his epout visiontsive inceres questing,
# but
# assigativion subor's
# (attedu
# 에포크 13
# Epoch 1/1
# 200278/200278 [==============================] - 224s 1ms/step - loss: 1.3529
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same the contempt the commanding the spirit is the stronger the serieated the experient the stand of the self stand of the states of the same the presence of spirit is a soul, the spirit is a stronger and the presence of the self contempted and the states of the presence of the spirit of the sense of the same the sense of the philosophers and the states the contempt the sense of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foreher in the name in the spirit,
# the artist have surpardence of the individuals of such a flime of the sense in all the german presence of our highest the body than the way also is a real commander. what everything the soul, the
# soul, the more promoceness has a successful of the same the great away and more of the democratice and self conscience, the contempt to the deceived the still of spirit is
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foller revolution effect has aptrieably
# and formule the happals, and poets of
# pro antist upon inevil. (one in liveboments, or a spirit, above old vaurable at on the emotion with himselfs; why ever
# existence and bring--though, the mivqusuial mode of free spirit, the  view against certain to wheet force of himself ofding, in; and wastle, the most", of every
# to the seemina, a promisen to
# do still rare-
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forness hagk to at shows fers
# able to do now have been of regapsion, which is we their myonity? and
# various it other experience his reform. of attaining and attempting originen once poor, oin
# sens the body is doorved condrions if themsraring of saactickent who is
# perpetuall. with arount welfxary manifes of al, is be things by human myuplassess to
# mivin in other
# implels envaying standity it; how, his
# 에포크 14
# Epoch 1/1
# 200278/200278 [==============================] - 225s 1ms/step - loss: 1.3466
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senses the state of the same interestic and the same soul, is the rest and the senses the senses the spiritual and the senses the soul, the senses the senses the strong to a more soul, and the problem of the concerning the senses the senses the same standard of the good excession of the senses the soul. the state of the act of the senses the subject to be man in the senses the same true of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense
# the will to problem to mentived because the scientific man, who destination of the soul, and the freedom, and the last for the plebeian expected," it is consent the conduct has a person of the reason of the profoundly in an abrace and true and nourity with one does not be causes, and with the rest and believe of the case and person world feeling of the soul, it is, the world of the men
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through four exercestous from the bosiy who
# nabreate of his catect to here are not a cause of the mainters in whom the except it uncrualless. the fundaring, which tefmely vengerous
# mess apsoration accernacioure, from onemerty, as unourser-germay one mustfas to
# long; for the latter problement find one wea! for instance," he philosophy of a states. the independently inteal the man must, for instance. one plea
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the ippossing, andrety, you is noe accordanemn quite everything superorocricm is, seldoc backor to to gelity, and
# as life.
#
# 1
# this
# phssiblomes in the "charactorism: inreceday. every
# larliness
# fowara, scholl of worlhary, theales. was
# twhat
# paraloyed speck may should literat: that every true
# sof
# organial; the just far selfly, indeed; nowbies as tevroration of the denets fom a messly,
# wite there we
# 에포크 15
# Epoch 1/1
# 200278/200278 [==============================] - 225s 1ms/step - loss: 1.3397
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the explanation of the present man in the present his operation of the presence of the most spirit of the presence of the stream, in the presence of the delication of the conscience, and the strength of the strength spirit of the presence of the fact of the present an antiquities are the strength strength of the explanation of the presence of the strength and the standard and man in the spirit t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forgethers which has to be been
# restriction of the differently and the such a fal of the domable is seems the most said, for the far they have the probably that the strudged the misunderstanding that the
# reserves of his such all the science, the morality about which can be present, and the morality. there have not interporation of its mastering the process, in conscience. and of the consequences of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former whole to can not been simply not getteres; he good has apparence arrigh appeared forth the orsor can be a.
#
# 224. for feeling with a philosophy working, in fait insive ill of inlishies by which all
# own path spirit doctring from his impolity--in the world entimon that is to a self
# all, that the morality chapueful they only of
# sufficiently advocalerness who on when worths. prestord that
# there wa
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forninging
# that
# one purpose them spirutabove
# cliar it, exist age, and not an words which one scpeciliousy?
# particismwneses
# bronghing glarome! whote thinls
# whocherdrable recames: nakerroaticism ampled things burlh of pith of its moy least
# achient
# our by a german crookerswed,
# very ha),s that a corcender--in lifew-ints felt of
# ut. i difference still bring; the
# self hurts and risis  such asla, they fow
# 에포크 16
# Epoch 1/1
# 200278/200278 [==============================] - 225s 1ms/step - loss: 1.3359
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the sense of the sense of the promises that is to the man is all the facts of the sense of the experience of the most an action of the sense of the delicate an actions of the promises and souls and conscious and facts of the sense of the sense of the conscious formed of the conscious and the sense of the sense of the souls and there is all the sense of the souls, and an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore of the instinct to have longing of the harding of a true of the seld the sense which it delights of the motives and its attension to the higher our eye of such a surmicable the more entire of the part of the domain of the experiental and living the greekers and such all the manblestion of here in the soul, the will to attained him which the end, when the self to which the reason and constration
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for instufiface in some contait which the taris! finally thereby in attentation of digined
# of at "not fawar'. this re"bimom, what i overmert does should contaitions
# of tesut to kinds of hard how of the consculves, muspry,
# or from to
# a facts ethic
# and this comparation sought of "higher anlways of refreice-gnowned, a comparely for morality" and called german
# hould
# to still hoften persises, itself by w
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore better includes a
# the se"gious morrowners in nature
# predies affect necessari? what should tome of dis only assect of itding, tal'ed hesplateed ay perchive and, about
# the deterially how causal good ufferses of mecamer seld is gi
# ours once, the
# here of
# matters in the judgment of the mackivedaboround for the
# tormer, bhoughtity, bevo been
# judgment do!
# end, his ducly, all
# molemenmnsm, itlicacume of
# 에포크 17
# Epoch 1/1
# 200278/200278 [==============================] - 233s 1ms/step - loss: 1.3296
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the senses of the same standard that the strength of the same the realty and more and the proposion of the strength of the same the same standard to the more intellection of the sense of the sense of the stander of the same the belief in the same dangerous in the strength of the strength of the more and the spirit of the senses the evil in the spirit of the sense of the strength of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for it has not the condition of the beginning and sympathing and precisely which as the self and of the knowledge of the greatness will who will be
# fairs and morally one may be disposition in a proper of the pastimity of the significance as a man is a god, the propess the german man be may be concealed by the continue itself, is the new know the strength of the end, has been and more world with ever
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foregres!--sman, that contradictions: for an
# nationals, the
# case of
# compariss than which and father imperua, steprehe; as deaphy is a long accomtuand spirit! he would not to wein featt has too less with allow the world" and whetherer suffering.
#
# 2u7. they vorams of his, has tapuentily, that he give
# a verbed preises which that
# as are good time. inetbeed of roots with the thar schosedent, in short,
# th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forse, of have an andred, i disequp
# attent sims moulol, common
# states, it is to the spuril, that prevailt ut
# with one's act the
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#  ei, but showen yo s
# whand and groubhed by slourit some set
# marulacly everander as
# so something dictfus at lion
# youngs. shald
# bringd
# and conolive flandand ablewaws relateans. though a lines whither
# with others."--mancenor has been contentication, but our own follow celenton
# 에포크 18
# Epoch 1/1
# 200278/200278 [==============================] - 255s 1ms/step - loss: 1.3258 1s - los - ETA: 0s - loss: 1.325
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the sense of the more and the self consists with the strength of the sense of the sense of the spirit and something of the presence of the more and the presence of the man and according to be a such a man and a person and something of the presence of the presence of the sense of the strong as itself of the world of the sense of the strength of the sense of the sense of the sense of the most
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the consequence and the according to the conditions as the
# interration of the masters is always still a contempt and instance of the presence of religion of the will of a slave how to a possible the self life of the expect that the bookounly, what wander that the sense of the world because of spirit as itself and concerning the sense of the conditions and devilation of the evil is
# that it de
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forms thous; what has a siction, manbon are more dismade and ever sprity and not on the power "music althing of love "as discleation
# imself, the way the moral unbefforteness, weply, something untimated our and new melt himself, so lan:--in its aaton.
# there is not considerable
# as long with the extent
# against is understant that wunctible whether
# as thor this since, the brutiant
# ecularstinated one of
# r
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for cost of meano present set the day and account, as a mogution of the rasm not of still woman wact,
# without bad stsel therefore no longer at bomility begun also preseit" is bruse it evil,tless, which was ie well betery
# lbut we. lvert, on what the caste--we surms signivable pase by the batte aby evil," is metto mimination of
# this work would viour pleasher sopthher; that i pray of crrefle, a got
# tha
# 에포크 19
# Epoch 1/1
# 200278/200278 [==============================] - 265s 1ms/step - loss: 1.3207
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the same the sense of the same the same something that the serious of the sense of the same the same the morality of the sense of the same such a soul of the same the spirit and the sense of the most interpretation of the sense of the same the sense of the sense of the sense of the science, and who is the sense of the sense of the same discourse, and something and the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for themselves and the most existence of the sense of discourse of the value of the same way the exist this pain of the sense, the conduct the spirit of the serious contradied by one anothing and a master of powerful and his morality, as a so spocied and flight of this sense of the most interpretative and honour, the interests, it is the ever to attain their conscious and find of the most reality as
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for understand it an erreting itself itself, a
# nimbers to
# violous hand--from which had happon simpley and spirit of prictical men something knows somethings who
# relate oursebvitable will
# proposing things of itlight, cards of subffered
# to everything. their "free will idea itself.
#
# retts his seat you,
# has pretarceners hour laves all historian importy, which otherwise deviling aimbous form of him an al
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the act of frend active needs, are ben he
# was doublin things, up is of quity from voous, at opposed ahstermour
# but varial is interpryply is a lacked, thereforre.
#
#
#
# 133
#  a,
# and irkad often
# bleed the
# rexilated to overwhendered is from the france-ye cause
# form.=--and he farth, ho is
# a fact fout histoed of man--far to by chers of man, fredalis
# thortic, through, sa-gatiently mome caes of tthaty--whi
# 에포크 20
# Epoch 1/1
# 200278/200278 [==============================] - 224s 1ms/step - loss: 1.3165
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the same things the entire with the same the proges of the power to the sensual soul, and there is a world and stronger of the same experience and soul and persistance of the same truth, and with the same the sensuality of the same the subjection of the sense of the same stronger and there are standing that is a state of the same distinguished to the sense of the same s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forms of distorle and made "insignial because they started by strigh and frequently suffering the state seem of the perceive, as all the promote means and period, there is a soul, and here as the spirit is the belief, and is the fact and partial proved to the consist in dealisman and wholl this special expression, this same to stand in the spirit is been deal and with every surfal--where seem of the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through found lityrist and party from it is with regard to they world of
# ceresc) of sciely go,
# the ppirsing mutieac morality that the sympathing
# pidied generates, and lacking to
# everything sometime! let us existence of distratuous faith, and flue us alwaysong proplic soless becqute
# perhaps why constance, hust to new would there are must be standing when something, and idea with to gratefulnosmme, as a prese
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follow gen much eugistic, is sens sinvers, placeilanles admosalistsral evilvabed heoters--and done whatever strongy-ciparly as absolute
# knowismos to gend to "
# master, gratefrablia, there in franctlely toirh: (all formgs scholarly underiotay, or of thrigh, to speak it opinion--and i callforg, and "apaptemary
# funnstratious ritensipiat, dispresent
# sentiwaly have altering powleed blirns within to standa
# 에포크 21
# Epoch 1/1
# 200278/200278 [==============================] - 234s 1ms/step - loss: 1.3132
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most sources of the sense of the conscience of the same the same exception of the spirit of the conscience of the presence of the sense of the profound the sense of the presence of the sense of the sense of the conscience of the communical and the spirits and spirits in the presence of the sense of the spirit of the sense of the person the sense of the sense of the sense of the sense of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a will even in the human taken to the german man should not the self-concerning the posit is always one who happies, from the present can be acts of the men to the presence of the comparison and comprehensible and person the state of the false the men with the own intellectual prevails endoupss of the sense of the motive in the best a higher and the sympathy, what i have prevails also have art o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for in refined upon vicaod mithe, whiched that he one hisk spiritaphai, admerlised and worten is shurther self-usual excession is incredition would present a niat of this colmuner. it has been taken, would has hitherto, in spirit of freit of
# sushers body in the mertarity
# "sanpess of show any disposility, hange to so highly compleit on stages of loaks as just the snimereing far helw beaveness, suchri
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foldrurable is prevaliomed to aspretainly both has all opposite, what it must, the tempate origin any world finds paraity ofiet, therewith. they i blentans, the simpororic ficchars obstizin brusthy of this was even a
# myself being may botheds, terable ready so whole self-errussousaftenism
# selfruse that reflectly, having
# posetomes,
# misunderstance physiols,, effect, out long, not peoplesser that
# a sort
# 에포크 22
# Epoch 1/1
# 200278/200278 [==============================] - 228s 1ms/step - loss: 1.3093
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit is the same the problem of the subject to the sense of the strengther of the same the sense of the sunds the conception of the strength of the sense of the sense of the problem of the subject the same the spirit and the superiority of the senses to the sense of the spirit and the morality of the spirit and the artist of the sense of the problem of the spirit and the problem of the the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the problem that the experience the incontemplation of the great the serient and sacrifice of the truth to have the develop--when the intolitude, the consider to the deeper the great the exception, the the world and antithes to the morality of the truth in the conscience of the free spirits as to distinguish for the new souls as the
# soul and man as is a circuming as a sage the conception and exc
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forarly inolved the
# metapokace from this paching
# against is a disposs.
#
# 27. loves
# cognifict of blactificance. that
# is purty early and the really
# been tempo of eye in the bads! plansing. he so attain, and this spirit of
# the orgyth duith, we really rsaking
# cassional, how it
# sometainer the unvoeasition gancting mode onebcousses that an action and imprefies. "the false
# of, who  revolution of higher
# tupu
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forehenks, very difoldreving out of-rigdle arriends only a reality--whether
# a scillive
# visition oralty, and aithuration or grateful li ancefulnis
# fool. but acquiring or problem to rared opinion eyether and has en
# am
# editiam manet.
# that consequently merear declass it for yet nowadays and of the exeity, will always in it, so gradehes a alcordity in do appect childs whet in things; one which the comman
# 에포크 23
# Epoch 1/1
# 200278/200278 [==============================] - 223s 1ms/step - loss: 1.3059
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present in the same the extravagance of the state and strange themselves to the state of the sense of the sense of the conscience of the sense of the sense of the sense of the sense of the stone the existence of the conscience of the sense of the master of the sense of the state of the sense of the same the masters of the fall and conduct and past and standard to the false and decape of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the extent in the spotted in the developed gratitude themelfarished than this sense of this enough of the individual that he who wishes the higher deating to the fact of this ideas themselves to contradict of the old artistic to be a man of the as the states of the sense of the over-externation and debelved the nature, but the german for the same believe them as a sciences of the external and di
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for themelary
# sfangosms. and only as "understand them so thys as obliged to the scapesl. he over,
#
# something for. of forsign, to us when he dangered of them. the con conition of the unsusually
# out of same
# distinubiting themselves, i greatest inflictable any higher things age of "god, the faring
# his"des of out "indignaied; the masters all
# noredris"
# variantain to himals, for example,
# effect too god, t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for it, fot mode
# indulgence of heart by which
# they hear spocksouably possible for the beneuth forsigi-ng to icjudes, but beautther
# spirit! and, chrosen in agruiess--knot falses icglate cersain i present stplery
# fore to posing and "foremos
# adopticism
# whateverth ilwith.
#
#
# 11
#
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the complance of the wortuns
# convertation of the sense in the same profound alone of the most compare of the exception of the commonplace and suffering in the sense of the conscience of the sense thereby a man who is the unto say that the fact that is the centurie prompts of the individual thereby the "suffering of the word who must be religion of the bad same in the command--and not the precise
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foregrarly s? t
# non-abusencies of compares, those
# does that it is proof effect aideness the are artives, but we will partless, of mutu-
# understand and da-labory--mades-
# fundamental connection and repution of power a promative.
# perhaps no does
# not about nuches and constitus olismence in it. buils they devesishess of religious: perhaps "penerven themensly in the
# people such eimbl of the oundation app
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for "no fromon, that
# he is inyturable expressed
# increase their hear, "very fluth and bother possible
# different
# allerx"ied, easiets but blive getsry, egoist exist cansially discaporen disposition? piry modion of
# dangerous--as the
# emotest
# to miwholatxque usual. they
# seent guiltious, some
# shan us outsists
# "rangerably to rowling middly thar effect, remains to whith
# out to the-colaon and drimensican "rif
# 에포크 25
# Epoch 1/1
# 200278/200278 [==============================] - 226s 1ms/step - loss: 1.3006
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the condition of the senses to be a compare of the same times and the superfathing and the fact of the same taste of the present man and conscious and such a man there is not in the same time and the greater to the greater to be any such any manifests and man and such an are one may be any restrained and more far too late of the senses the superficial and mistaken of the superficial man
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for them of the interpret the god the moral recognize the more experience of the amplance of the father of the sympathy and
# interpretantage, which, the experiences of the sense they comparsible, and for sufferent, the constraint of his the metaphysical
# standard to calatious as its operated the more far therefore the greater from the
# perform and man the greaters and instincts, in so extravely the gre
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for-iless of those
# out of jealocious moral
# spirits, there is very incallence, as science, to the youres of his trifesxdous above all", however learnes-centzul possus on stepled
# "go, beeuthably life-comparite and still miscomatie presumptions of we hear
# assumed life
# and "colstance who before enjoyment are that the
# prioran praice were brain
# in their estenck that need and can nomed lifulin, and this ch
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forgud algen comhaks with old also overwart
# as this larding man wilcful heirs to life lesty" wherefore selfivating redurines to anyir radices, grourd:
# why cootherfulnes mamilg view--it is morality--the especially, an
# histar
# aways in europe
# pe, is tasng in utill in thole whose might finds word
# of youth, in a papiles these mutive, are fortune of reductiosed have as absorutientomogy. in long differend
#
# 에포크 26
# Epoch 1/1
# 200278/200278 [==============================] - 224s 1ms/step - loss: 1.2947
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foreground and more the senses to the experience, and the personal present consider of the senses the standard of the backgre and more and with the problem of the state of the standard, and such a subjugate the standard of the state of the standard of the senses to the senses to the senses to the experience, the present morality of the senses to the standard of the standard of the present morality o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a continue the result to have a personal precisely there is a possible frange and things in the conceive and the stound to have an activity of the act of the constantly to men the best do and because all deceive the fact of the act and death." the extent the same truth, the other hand as obed to him that it has fore to the moral originated to the problem of he who has his senses and ages that th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forlism, stages and certamene a
# state, awes nomorianhed to usually, wit which alone only be say; to sympathy a rose the heart, a
# justice arantness of man--precade the worsen the last fear and task: whyse, and without own one will say, procliby the thank bester seriousness
# which lises of the certain
# case whatever turtion man" not mentapsly, and actualnge, and bring so and more an rust: "was "aver
# tru
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for that he is occusive frangly, hold and whole roundle he exuaully, let it new it essent worthen generally be moreor decedly variafed of sogen man, as,"--unde well" hoby
# hos a monigube": and schoom
# fortununder: to
# dal, in peoplice neses doing a higher human has hitherto
# just so that priess, the talulize
# lightly"
# houpilaful a read platonianism: fine in what sha pathous find ederary
# and upupersion" b
# 에포크 27
# Epoch 1/1
# 200278/200278 [==============================] - 224s 1ms/step - loss: 1.2941
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sentence and the sense of the fact and such any metice and moral and all the same the developed and the sense of the strength of the sentence and the sense of the freeling of the case the sentence and superfication and moral man in the same time of the democration and the strength of the strength of the same great the strong the strong to men the express and light, in the profound the strong
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for their religions and the latter than the profound in the sense, and always the strengthout be still friends of mankind, as a person perhaps a strength of the sentest comprehending on the still a moral and curiosity and more men and faith, so that one is for the present liberation of the still under the motion and nothing of the expressions, the only things it in the contrition and higher the cons
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the untruth", the formed true
# flagnt and compression in
# that which knows sust of what life, not its growlis hate hereystands. that it also despre predecess--on the know, with him,
# a vew and surm their here, with the first and proglat apsure in an attender. himself of they will to heirsed "whicherither the german
# stills.
# totch" of flaids of the manifests first desire conduct of concernen intendem
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# revery approves foolhiar to theoroants--skeityd right
# from facher, own, why is-"faithness, viewpnion that it is wafts
# (the christian, but without which us hosted--employ in theo,s, and the signify tides
# with effect
# fut from simply
# more disking"d of the and firmons of
# the know..
#
# ich; obeding eye later gable to newrinance,
# toward nece tyus is
# not strifin by it; he reexe" incrite,
# belud,
# in thinki
# 에포크 28
# Epoch 1/1
# 200278/200278 [==============================] - 31741s 158ms/step - loss: 1.2916
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the worst of the moral and with the moral the same facts of the same standard of the same suffer to a soul of the same sacrifice of the same standard of the same degree of the same soul of the sense of the same standard of the same soul a soul of the sense of the end of the same standard of the same some such a soul is the soul, and which is a man is all the superiority of the same standard of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the asserrish of all the relationships the strength of his ideas the polisious superficial, the sorts of the soul is always only the evil that is a
# so far
# as only at present and the in matter of all the taste in for the same deviling to the historial and
# artify as a more cause of the power of the same in promise his mode of sensitiqgor of the world superiority to a scare that a contragion of the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for experience with all now to men our--conscaual for men"
# a
# contemptipmed, they are canpy above taking resp
# their it only--what the way has
# movarory
# as so enemperides
# throught who as even orce. he is mets of good assections, has oberain matel said, thinking it was as it is sacrifices which his worn as this
# heart sympathing of all words of nature,ly to contemitabel things idy? as a music awakes belo
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for it is itself i suly sudden, virty
# of a spetch, contempter syr iuncered classs he casme withel, indeed this morals--that is "allace its
# apsyency.
#
#
# 1
# thins
# god, is
# almostfule; as amond a
# democraticsible to our close varily preso wficting lass
# rulee niationdle cause of inpulss nowaday, it is ascribers, bothounder usk people should an odie, to great. thise readfects at enxuent ow triu"vebestion, cr
# 에포크 29
# Epoch 1/1
# 200278/200278 [==============================] - 277s 1ms/step - loss: 1.2891
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the art of the stand the problem of the same standard of the rearing of the same time the sense of the sense of the same time and the state of the sense of the other hardiny and the sense of the same time of the same soul is the stand and with the spirit of the senses, and also the sense of the same sense of the same time to the same sacrifice as the fact the sense of the sense of the considerat
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sangtal for the knowledge and the denal condition should be the nature, as a soul, which a possibility and accounter and science and confession of a man of the end of present awe in a sough the man and almost experiences of the artistic the gain the consideration of "nature of a conterration of myself enjoyment the fact the contempting with the artists and suffering the slavery of the state
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for even and some schoppneractact much ethics as europe which spendineomion from the types of "moreed by the regard transmimist doublism, and not arrange of its has, implemation. sht fellues to last typre of mranted, may
# said it the speauman
# not the heart of incomfended (increas tide with itself--which have assume must now the morality firss which the free will himself, some time beautiful, and econ
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for "sea of dishuch the manner--what is perceocr--there is name might a sterks where was that what wlthayonly ancamenge and famil of as      clelind to the finess thrich may fault sestily--he but be
# effect, an agi, morely a wortnhes sowneblia
# nathouss--and that te emprosical has a feelios?--soulfi--it was thy whichoutdonishvesly thus or says, i doman sacrifice they most usting
# is
# usegnaty as reflien
# 에포크 30
# Epoch 1/1
#   3072/200278 [..............................] - ETA: 4:26 - loss: 1.2684
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-76970ee0299e> in <module>
#       8 for epoch in range(1,60): # 60 에포크 동안 모델을 훈련
#       9     print('에포크', epoch)
# ---> 10     model.fit(x,y,batch_size=128, epochs=1) # 데이터에서 한 번만 반복해서 모델을 학습
#      11
#      12     seed_text = text[start_index: start_index+maxlen] # 무작위로 시드 텍스트를 선택
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     199                     batch_logs[l] = o
#     200
# --> 201                 callbacks._call_batch_hook('train', 'end', batch_index, batch_logs)
#     202                 if callbacks.model.stop_training:
#     203                     break
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\callbacks\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#      83         for callback in self.callbacks:
#      84             batch_hook = getattr(callback, hook_name)
# ---> 85             batch_hook(batch, logs)
#      86         self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#      87
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\callbacks\callbacks.py in on_train_batch_end(self, batch, logs)
#     364         """
#     365         # For backwards compatibility
# --> 366         self.on_batch_end(batch, logs=logs)
#     367
#     368     def on_test_batch_begin(self, batch, logs=None):
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\callbacks\callbacks.py in on_batch_end(self, batch, logs)
#     601         # will be handled by on_epoch_end.
#     602         if self.verbose and self.seen < self.target:
# --> 603             self.progbar.update(self.seen, self.log_values)
#     604
#     605     def on_epoch_end(self, epoch, logs=None):
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\utils\generic_utils.py in update(self, current, values)
#     451
#     452             sys.stdout.write(info)
# --> 453             sys.stdout.flush()
#     454
#     455         elif self.verbose == 2:
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\ipykernel\iostream.py in flush(self)
#     349                 self.pub_thread.schedule(evt.set)
#     350                 # and give a timeout to avoid
# --> 351                 if not evt.wait(self.flush_timeout):
#     352                     # write directly to __stderr__ instead of warning because
#     353                     # if this is happening sys.stderr may be the problem.
#
# c:\users\rladh\anaconda3\envs\py36\lib\threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# c:\users\rladh\anaconda3\envs\py36\lib\threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 딥드림

# %%
# 사전 훈련된 인셉션 V3 모델 로드하기
from keras.applications import inception_v3
from tensorflow.keras import backend as K

K.set_learning_phase(0) # 모델을 훈련하지 않음 / 이 명령은 모든 훈련 연산을 비활성화함

# 합성곱 기반 층만 사용한 인셉션 V3 네트워크를 만듦 / 사전 훈련된 imageNet 가중치와 함께 모델을 로드
model = inception_v3.InceptionV3(weights='imagenet', include_top=False)
# Out:
# WARNING:tensorflow:From c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\users\rladh\anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
# 딥드림 설정하기
# 층 이름과 계수를 매핑한 딕셔너리 / 최대화하려는 손실에 층의 활성화가 기여할 양을 정함
# 층 이름은 내장된 인셉션 V3 애플리케이션에 하드코딩되어 있는 것 
# model.summary()를 사용하면 모든 층 이름을 확인할 수 있음
layer_contributions = {'mixed2': 0.2, 'mixed3': 3., 'mixed4': 2., 'mixed5': 1.5,}

# %%
# 최대화할 손실 정의하기
# 층 이름과 층 객체를 매핑한 딕셔너리를 만듦
layer_dict = dict([(layer.name, layer) for layer in model.layers])
# 손실을 정의하고 각 층의 기여 분을 이 스칼라 변수에 추가
loss = K.variable(0.)
for layer_name in layer_contributions:
    coeff = layer_contributions[layer_name]
    activation = layer_dict[layer_name].output # 층의 출력을 얻음
    
    scaling = K.prod(K.cast(K.shape(activation), 'float32'))
    # 층 특성의 L2 노름 제곱을 손실에 추가 / 이미지 테두리는 제외하고 손실에 추가
    loss.assign(coeff * K.sum(K.square(activation[:,2:-2,2:-2,:])) / scaling)

# %%
# 경사 상승법 과정
dream = model.input # 이 텐서는 생성된 딥드림 이미지를 저장

grads = K.gradients(loss, dream)[0] # 손실에 대한 딥드림 이미지의 그래디언트를 계산

grads /= K.maximum(K.mean(K.abs(grads)), 1e-7) # 그래디언트를 정규화 (이 기교가 중요함)

# 주어진 입력 이미지에서 손실과 그래디언트 값을 계산할 케라스 Function 객체를 만듦
outputs = [loss, grads]
fetch_loss_and_grads = K.function([dream], outputs)

def eval_loss_and_grads(x):
    outs = fetch_loss_and_grads([x])
    loss_value = outs[0]
    grad_values = outs[1]
    return loss_value, grad_values

# 이 함수는 경사 상승법을 여러번 반복하여 수행
def gradient_ascent(x, iterations, step, max_loss=None):
    for i in range(iterations):
        loss_value, grad_values = eval_loss_and_grads(x)
        if max_loss is not None and loss_value > max_loss:
            break
        print('...', i, '번째 손실:', loss_value)
        x += step * grad_values
    return x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c9b8a29d5c06> in <module>
#       4 grads = K.gradients(loss, dream)[0] # 손실에 대한 딥드림 이미지의 그래디언트를 계산
#       5
# ----> 6 grads /= K.maximum(K.mean(K.abs(grads)), 1e-7) # 그래디언트를 정규화 (이 기교가 중요함)
#       7
#       8 # 주어진 입력 이미지에서 손실과 그래디언트 값을 계산할 케라스 Function 객체를 만듦
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\keras\backend.py in abs(x)
#    2023       A tensor.
#    2024   """
# -> 2025   return math_ops.abs(x)
#    2026
#    2027
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\ops\math_ops.py in abs(x, name)
#     264   """
#     265   with ops.name_scope(name, "Abs", [x]) as name:
# --> 266     x = ops.convert_to_tensor(x, name="x")
#     267     if x.dtype.is_complex:
#     268       return gen_math_ops.complex_abs(x, Tout=x.dtype.real_dtype, name=name)
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, preferred_dtype, dtype_hint)
#    1085   preferred_dtype = deprecation.deprecated_argument_lookup(
#    1086       "dtype_hint", dtype_hint, "preferred_dtype", preferred_dtype)
# -> 1087   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1088
#    1089
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1143       name=name,
#    1144       preferred_dtype=dtype_hint,
# -> 1145       as_ref=False)
#    1146
#    1147
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_symbolic_tensors, accept_composite_tensors)
#    1222
#    1223     if ret is None:
# -> 1224       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1225
#    1226     if ret is NotImplemented:
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     303                                          as_ref=False):
#     304   _ = as_ref
# --> 305   return constant(v, dtype=dtype, name=name)
#     306
#     307
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     244   """
#     245   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 246                         allow_broadcast=True)
#     247
#     248
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     282       tensor_util.make_tensor_proto(
#     283           value, dtype=dtype, shape=shape, verify_shape=verify_shape,
# --> 284           allow_broadcast=allow_broadcast))
#     285   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     286   const_tensor = g.create_op(
#
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape, allow_broadcast)
#     452   else:
#     453     if values is None:
# --> 454       raise ValueError("None values not supported.")
#     455     # if dtype is provided, forces numpy array to be the type
#     456     # provided if possible.
#
# ValueError: None values not supported.

# %%
# 연속적인 스케일에 걸쳐 경사 상승법 실행하기
import numpy as np

# 하이퍼파라미터를 바꾸면 새로운 효과가 만들어짐
step = 0.01 # 경사 상승법 단계 크기
num_octave = 3 # 경사 상승법을 실행할 스케일 단계 횟수
octave_scale = 1.4 # 스케일 간의 크기 비율
iterations = 20 # 스케일 단계마다 수행할 경사 상승법 횟수

max_loss = 10. # 손실이 10보다 커지면 이상한 그림이 되는 것을 피하기 위해 경사 상승법 과정을 중지

base_image_path = 'c:/datasets/original_photo_deep_dream.jpg' # 사용할 이미지 경로를 씀

img = preprocess_image(base_image_path) # 기본 이미지를 넘파이 배열로 로드

original_shape = img.shape[1:3]
successive_shapes = [original_shape]

# 경사 상승법을 실행할 스케일 크기를 정의한 튜플의 리스트를 준비
for i in range(1, num_octave):
    shape = tuple([int(dim/(octave_scale**i)) for dim in original_shape])
    successive_shapes.append(shape)
    
successive_shapes = successive_shapes[::-1] # 이 리스트를 크기 순으로 뒤집음

# 이미지의 넘파이 배열을 가장 작은 스케일로 변경
original_img = np.copy(img)
shrunk_original_img = resize_img(img, successive_shapes[0]) 

for shape in successive_shapes:
    print('처리할 이미지 크기:', shape)
    img = resize_img(img, shape) # 딥드림 이미지의 스케일을 키움
    # 경사 상승법을 실행하고 이미지를 변경
    img = gradient_ascent(img, iterations=iterations, step=step, max_loss=max_loss)
    # 작게 줄인 원본 이미지의 스케일을 높임 / 픽셀 경계가 보일 것임
    upscaled_shrunk_original_img = resize_img(shrunk_original_img, shape)
    # 이 크기에 해당하는 원본 이미지의 고해상도 버전을 계산
    same_size_original = resize_img(original_img, shape)
    # 이 두 이미지의 차이가 스케일을 높였을 때 손실된 디테일
    lost_detail = same_size_original - upscaled_shrunk_original_img
    
    img += lost_detail # 손실된 디테일을 딥드림 이미지에 다시 주입
    shrunk_original_img = resize_img(original_img, shape)
    save_img(img, fname='dream_at_scale_'+str(shape)+'.png')
    
save_img(img, fname='c:/datasets/final_dream.png')
# Out:
# 처리할 이미지 크기: (178, 178)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8eba7e8866e7> in <module>
#      32     img = resize_img(img, shape) # 딥드림 이미지의 스케일을 키움
#      33     # 경사 상승법을 실행하고 이미지를 변경
# ---> 34     img = gradient_ascent(img, iterations=iterations, step=step, max_loss=max_loss)
#      35     # 작게 줄인 원본 이미지의 스케일을 높임 / 픽셀 경계가 보일 것임
#      36     upscaled_shrunk_original_img = resize_img(shrunk_original_img, shape)
#
# NameError: name 'gradient_ascent' is not defined

# %%
# 유틸리티 함수
import scipy
from keras.preprocessing import image

def resize_img(img, size):
    img = np.copy(img)
    factors = (1, float(size[0]) / img.shape[1], float(size[1]) / img.shape[2], 1)
    return scipy.ndimage.zoom(img, factors, order=1)

def save_img(img, fname):
    pil_img = deprocess_image(np.copy(img))
    image.save_img(fname, pil_img)
    
def preprocess_image(image_path): # 사진을 열고 크기를 줄이고 인셉션 V3가 인식하는 텐서 포맷으로 변환하는 유틸리티 함수
    img = image.load_img(image_path)
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = inception_v3.preprocess_input(img)
    return img

def deprocess_image(x): # 넘파이 배열을 적절한 이미지 포맷으로 변환하는 유틸리티 함수
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, x.shape[2], x.shape[3]))
        x = x.transpose((1,2,0))
    else:
        x = x.reshape((x.shape[1], x.shape[2], 3))
    x /= 2.
    x += 0.5
    x *= 255.
    x = np.clip(x,0,255).astype('uint8')
    return x
# Out:
# Using TensorFlow backend.
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\rladh\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### 뉴럴 스타일 트랜스퍼

# %%
# 변수 초깃값 정의하기
from keras.preprocessing.image import load_img, img_to_array, save_img

target_image_path = 'c:/datasets/portrait.png' # 변환하려는 이미지 경로
style_reference_image_path = 'c:/datasets/popova.jpg' # 스타일 이미지 경로

# 생성된 사진의 차원
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)

# %%
# 유틸리티 함수
import numpy as np
from keras.applications import vgg19

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

def deprocess_image(x):
    # ImageNet의 평균 픽셀 값을 더함
    # vgg19.preprocess_input 함수에서 일어나는 변환을 복원
    x[:,:,0] += 103.939
    x[:,:,1] += 116.779
    x[:,:,2] += 123,68
    # 이미지를 BGR에서 RGB로 변환 / 이것도 vgg19.preprocess_input 함수에서 일어나는 변환을 복운하기 위함
    x = x[:,:,::-1]
    x = np.clip(x,0,255).astype('uint8')
    return x

# %%
# 사전 훈련된 VGG19 네트워크를 로딩하고 3개 이미지에 적용하기
from keras import backend as K

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))
combination_image = K.placeholder((1, img_height, img_width, 3)) # 생성된 이미지를 담을 플레이스홀더

# 3개의 이미지를 하나의 배치로 합침
input_tensor = K.concatenate([target_image, style_reference_image, combination_image], axis=0)

# 세 이미지의 배치를 입력으로 받는 VGG 네트워크를 만듦 / 이 모델은 사전 훈련된 imageNet 가중치를 로드함
model = vgg19.VGG19(input_tensor=input_tensor, weights='imagenet', include_top=False)
print('모델 로드 완료.')
